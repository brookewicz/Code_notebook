# %% [markdown]
# # Bleaching samples

# %% [markdown]
# ## update sample type
# - everything is healthy or diseased right now,
# -> change to bleached based sampling notes
# -> then crosscheck with colonydata?

# %%
import numpy as np
import pandas as pd
import os
import re

# %%
# upload sample and colony data 
sample=pd.read_csv('../sctld/SCTLD_samples/Sample_Data/CBC_samples.csv')
colony=pd.read_csv('../sctld/SCTLD_samples/Sample_Data/CBC_ColonyData.csv')

# %%
sample.head()
# Out:
#    Month_year Country Location CollectionDate Transect  TransectNum OldTagNum  \
# 0      122022     BEL      CBC        12/5/22   CURLEW            4       NaN
# 1       92023     BEL      CBC        9/27/23   CBC30N            1       NaN
# 2       92023     BEL      CBC        9/25/23   CBC30N            1       NaN
# 3       92023     BEL      CBC        9/25/23   CBC30N            1       NaN
# 4       92023     BEL      CBC        9/25/23   CBC30N            1       NaN
#
#   NewTagNum Species Time_sampled Time_processed    Sample_type SampleNum  \
# 0        77    OFAV          NaN            NaN    Core_frozen        18
# 1         1    SSID          NaN            NaN  Core_RNAlater       185
# 2         2    PAST          NaN            NaN  Core_RNAlater       171
# 3         3    SSID          NaN            NaN  Core_RNAlater       173
# 4        12    PSTR          NaN            NaN  Core_RNAlater       177
#
#      Health_status                Sampling_notes           Tubelabel_species  \
# 0          Healthy                           NaN   122022_BEL_CBC_T4_18_OFAV
# 1  Diseased_Margin  only margin sample available  092023_BEL_CBC_T1_185_SSID
# 2          Healthy                       CLP 90%  092023_BEL_CBC_T1_171_PAST
# 3          Healthy               CLP 80%; DC 20%  092023_BEL_CBC_T1_173_SSID
# 4          Healthy                         No CL  092023_BEL_CBC_T1_177_PSTR
#
#   Sample_physical_location Extraction_physical_location Date_sequenced Notes
# 0                      NaN                          NaN            NaN   NaN
# 1       UML_NARWHAL_R1_B10                          NaN            NaN   NaN
# 2       UML_NARWHAL_R1_B10           UML_NARWHAL_R2_B12            NaN   NaN
# 3       UML_NARWHAL_R1_B10           UML_NARWHAL_R2_B12            NaN   NaN
# 4       UML_NARWHAL_R1_B10           UML_NARWHAL_R2_B12            NaN   NaN

# %%
colony.head()
# Out:
#    Unnamed: 0 Date_InitialTag Transect  TransectNum OldTagNum NewTagNum  \
# 0         1.0         6/21/19   CBC30N            1       349         1
# 1         2.0         6/21/19   CBC30N            1       334         2
# 2         3.0         6/21/19   CBC30N            1       346         3
# 3         4.0        10/15/19   CBC30N            1       407         4
# 4         5.0         6/24/19   CBC30N            1       394         5
#
#   Species  Meter  Meters_90 Direction  ...  082024_Percentage  \
# 0    SSID    1.5        0.5     right  ...                NaN
# 1    PAST    1.4        0.1      left  ...                NaN
# 2    SSID    6.3        0.8     right  ...                NaN
# 3    PSTR    6.5        0.5     right  ...                NaN
# 4    SSID    4.3        1.2      left  ...                NaN
#
#                                         Notes_082024  122024_Condition  \
# 0                                                NaN       Not_visited
# 1  sample lower colony (original colony); inc old...               NaN
# 2                       90% CLP; some discoloration                 DC
# 3                                                NaN       Not_visited
# 4                                                NaN                DC
#
#   122024_Percentage   Notes_122024 062025_Condition 062025_Percentage  \
# 0               NaN       Diseased         Diseased               NaN
# 1               NaN            NaN          Healthy               NaN
# 2               10%  30% mortality         Diseased               NaN
# 3               NaN           Dead              NaN               NaN
# 4               10%  80% mortality         Diseased               NaN
#
#    Notes_062025 immune_y/n checked_colonies
# 0           NaN          n                x
# 1           NaN          y                x
# 2           NaN          y                x
# 3           NaN          n                x
# 4           NaN          n                x
#
# [5 rows x 56 columns]

# %%
# search for sampling notes with clp or clb 

#if col contains clb or clp 
# replace status with paled or bleached tissue
sample.loc[
    sample['Sampling_notes'].str.contains('CLP', case=False, na=False),
    'Health_status'] = 'Paled_Tissue'

# CLB → Bleached_Tissue
sample.loc[
    sample['Sampling_notes'].str.contains('CLB', case=False, na=False),
    'Health_status'] = 'Bleached_Tissue'

# %%
clb_sample = sample[
    (sample['Health_status'] == 'Bleached_Tissue') |
    (sample['Health_status'] == 'Paled_Tissue')
]

# %%
clb_sample
# Out:
#       Month_year Country Location CollectionDate  Transect  TransectNum  \
# 2          92023     BEL      CBC        9/25/23    CBC30N            1
# 3          92023     BEL      CBC        9/25/23    CBC30N            1
# 12         92023     BEL      CBC        9/25/23    CBC30N            1
# 13         92023     BEL      CBC        9/27/23    CBC30N            1
# 14         92023     BEL      CBC        9/27/23    CBC30N            1
# ...          ...     ...      ...            ...       ...          ...
# 2268       62025     BEL      CBC        5/30/25    CBC30N            1
# 2269       62025     BEL      CBC        5/30/25    CBC30N            1
# 2270       62025     BEL      CBC        5/30/25    CBC30N            1
# 2491       62025     BEL      CBC         6/2/25  Hangman             6
# 2492       62025     BEL      CBC         6/2/25  Hangman             6
#
#      OldTagNum NewTagNum Species Time_sampled Time_processed    Sample_type  \
# 2          NaN         2    PAST          NaN            NaN  Core_RNAlater
# 3          NaN         3    SSID          NaN            NaN  Core_RNAlater
# 12         NaN        24    MCAV          NaN            NaN  Core_RNAlater
# 13         NaN        25    OANN          NaN            NaN  Core_RNAlater
# 14         NaN        16    SSID          NaN            NaN  Core_RNAlater
# ...        ...       ...     ...          ...            ...            ...
# 2268       NaN        22    OANN         9:39          10:49  Core_RNAlater
# 2269       NaN        25    OANN         9:50          10:51    Core_frozen
# 2270       NaN        25    OANN         9:50          10:51  Core_RNAlater
# 2491       NaN        26    OANN        10:58          11:32    Core_frozen
# 2492       NaN        26    OANN        10:58          11:32  Core_RNAlater
#
#      SampleNum    Health_status                   Sampling_notes  \
# 2          171     Paled_Tissue                          CLP 90%
# 3          173     Paled_Tissue                  CLP 80%; DC 20%
# 12         174     Paled_Tissue                          CLP 10%
# 13         178     Paled_Tissue                          CLP 15%
# 14         194  Bleached_Tissue                          CLB 90%
# ...        ...              ...                              ...
# 2268      1619     Paled_Tissue  Colony 60% clp, Healthy sample
# 2269      1820  Bleached_Tissue  Colony 10% CLB, Healthy sample
# 2270      1620  Bleached_Tissue  Colony 10% CLB, Healthy sample
# 2491      1980     Paled_Tissue                          10% CLP
# 2492      1780     Paled_Tissue                          10% CLP
#
#                 Tubelabel_species Sample_physical_location  \
# 2      092023_BEL_CBC_T1_171_PAST       UML_NARWHAL_R1_B10
# 3      092023_BEL_CBC_T1_173_SSID       UML_NARWHAL_R1_B10
# 12     092023_BEL_CBC_T1_174_MCAV       UML_NARWHAL_R1_B10
# 13     092023_BEL_CBC_T1_178_OANN       UML_NARWHAL_R1_B10
# 14     092023_BEL_CBC_T1_194_SSID       UML_NARWHAL_R1_B10
# ...                           ...                      ...
# 2268  062025_BEL_CBC_T1_1619_OANN       UML_Narwhal_R3_B43
# 2269                          NaN                      NaN
# 2270  062025_BEL_CBC_T1_1620_OANN       UML_Narwhal_R3_B43
# 2491                          NaN                      NaN
# 2492  062025_BEL_CBC_T6_1780_OANN       UML_Narwhal_R3_B44
#
#      Extraction_physical_location Date_sequenced Notes
# 2              UML_NARWHAL_R2_B12            NaN   NaN
# 3              UML_NARWHAL_R2_B12            NaN   NaN
# 12             UML_NARWHAL_R2_B12            NaN   NaN
# 13             UML_NARWHAL_R2_B12            NaN   NaN
# 14             UML_NARWHAL_R2_B11            NaN   NaN
# ...                           ...            ...   ...
# 2268                          NaN            NaN   NaN
# 2269                          NaN            NaN   NaN
# 2270                          NaN            NaN   NaN
# 2491                          NaN            NaN   NaN
# 2492                          NaN            NaN   NaN
#
# [345 rows x 20 columns]

# %%
# other option is to match the colony data with sample data and based on the percentage, fix the tissue vs margin?
