# %% [markdown]
# # Crosscheck health statuses
# - continuation of BleachedSamples.ipynb
# - crosscheck sample health statuses with colony conditions
# - right now am looking for mismatches in health statuses (8/25/2025) to manually investigate and fix discrepencies
# - next: want to make sure each colony has the correct num of samples per sample date

# %%
import numpy as np
import pandas as pd
import os
import re

# %%
# upload sample and colony data 
sample=pd.read_csv('~/Documents/sctld/SCTLD_samples/Sample_Data/CBC_samples.csv')
colony=pd.read_csv('~/Documents/sctld/SCTLD_samples/Sample_Data/CBC_ColonyData.csv')
colony.drop(columns="Unnamed: 0",inplace=True)

# %%
# add colony ID - t# newtagnum species
sample = sample.copy()
sample['TransectNum_str'] = 'T' + sample['TransectNum'].astype(str)
sample['colony_id'] = sample[['TransectNum_str', 'NewTagNum', 'Species']].astype(str).agg('_'.join, axis=1)
sample.drop(columns='TransectNum_str', inplace=True)

# %%
# add colony ID - t# newtagnum species
colony = colony.copy()
colony['TransectNum_str'] = 'T' + colony['TransectNum'].astype(str)
colony['colony_id'] = colony[['TransectNum_str', 'NewTagNum', 'Species']].astype(str).agg('_'.join, axis=1)
colony.drop(columns='TransectNum_str', inplace=True)

# %%
# filter for UML samples for crosschecking
sample_subset=sample[
    (sample['Sample_type'] == 'Core_EtOH') |
    (sample['Sample_type'] == 'Core_RNAlater')
]

# make species list 
species_list=sample['Species'].unique().tolist()

# extract condition columns 
cond_cols=['colony_id'] + colony.columns[colony.columns.str.contains('_Condition')].tolist()

# %%
# make merged df for everything

# filter colony data for conditions 
small_colony=colony.loc[:,cond_cols]

# and pivot
conditions_long=small_colony.melt(id_vars='colony_id', 
                          var_name='Month_year', 
                          value_name='colony_condition')

# extract month_year from column names to match sample data format
conditions_long['Month_year'] = conditions_long['Month_year'].str.extract(r'(\d+)').astype(int)
# add back in colony data 
cols_keep=['colony_id','Date_InitialTag','Transect','Species','immune_y/n','Date_DocumentedMortality']
colony_filtered=conditions_long.merge(colony[cols_keep],
                                      on='colony_id', 
                                      how='left')

# filter sample data (USING SUBSET FOR NOW) 
filtered_samples=sample_subset.loc[:,('colony_id','Month_year','Health_status','Sampling_notes','Tubelabel_species')] 
# rename column for sample health statuses 
filtered_samples = filtered_samples.rename(columns={'Health_status': 'sample_condition'})

# merge colony and sample dfs by colony id and monthyear
merged = pd.merge(
    colony_filtered,
    filtered_samples,
    on=['colony_id', 'Month_year'],
    how='outer'
)

# remove rows with no sample 
merged=merged[merged['Tubelabel_species'].notna()]

# %%
merged['sample_condition'].unique()
# Out:
# array(['Diseased_Margin', 'Diseased_Tissue', 'Healthy', 'Bleached_Tissue',
#        'unknown', 'Unknown'], dtype=object)

# %%
print(merged['colony_condition'].unique())
# fix spaces 
merged.loc[merged['colony_condition']=="Healthy ",'colony_condition']="Healthy"
# Out:
# ['Diseased' 'Healthy' nan 'CLP' 'Diseased, CLP' 'Diseased, CLB' 'CLB,CLP'
#  'DC' 'CLB' 'CLP,CLB' 'Diseased_Other' 'CLB,DC' 'Diseased_Other, CLP'
#  'CLP,DC' 'Not_Visited' 'Not_visited']

# %%
# create function to crosscheck colony health with samples 

def status_match(group):
    # get the condition and list sample statuses of each colony at each monthyear (by row) 
    cond = group['colony_condition'].iloc[0]
    if pd.isna(cond):
        return all(pd.isna(s) for s in group['sample_condition'])
    # turned into string to prevent crashes from NAs
    statuses = group['sample_condition'].dropna().tolist()
    month = group['Month_year'].iloc[0]
    immune_dates = [112023, 122023, 12024, 22024, 62024, 82024, 122024] 

    # match colony conditions to sample conditions 
    # if colony_condition is healthy, sample = healthy 
    if cond == 'Healthy':
        return all(s == 'Healthy' for s in statuses)

    # if condition is diseased healthy = diseased_margin and diseased_tissue (but rn these are on 2 diff rows)
    elif cond in ['Diseased','Diseased_Other']:
        return all(x in statuses for x in ['Diseased_Tissue', 'Diseased_Margin'])

    # if condition is clp | clb = bleached_tissue 
    elif any(term in cond for term in ['CLP','CLB']):
        return all(x in statuses for x in ['Bleached_Tissue'])
    
    # if condition is Not_visited, sample = NaN
    # if condition is Dead, sample = NaN 
    elif cond in ['Dead', 'Not_Visited','Not_visited','not_visited','NAN']:
        return all(pd.isna(s) for s in group['sample_condition'])

    # if condition is na, sample should also be na 
    elif pd.isna(cond):
        return all(pd.isna(s) for s in group['sample_condition'])

    # exclude False matches if the colony is non-immune during an immune sampling point 
    # list of immune dates 
    
    # if coral is NOT immune during an immune date 
    elif group['immune_y/n'].iloc[0]=='n' and month in immune_dates:
        # it is ok if the sample status is na 
        return all(pd.isna(s) for s in group['sample_condition'])

    ## UGH but this has to exclude T5 and T6 during 01/2024 and 042024 respectively because they were newly tagged then 

    # any mismatches return as false 
    else:
        return False

# %%
# crosscheck colony and sample conditions

checks = []
    # check each 'group' (unique combos of colony and monthyear) and store results in 'checks' list
for (colony_id, month), group in merged.groupby(['colony_id', 'Month_year']):
    checks.append({
        'colony_id': colony_id,
        'Species': group['Species'].iloc[0],
        'immune_y/n': group['immune_y/n'].iloc[0],
        'Date_InitialTag': group['Date_InitialTag'].iloc[0],
        'Month_year': month,
            
        # run function &
        # create col containing results of the function that matches statuses
        'Match': status_match(group),
            
        'colony_condition': group['colony_condition'].iloc[0],
        'sample_condition': group['sample_condition'].tolist(),
        'sample_ids': group['Tubelabel_species'].tolist(),
        'mortality_date' : group['Date_DocumentedMortality'].iloc[0]
})
# convert to dataframe
checks_df=pd.DataFrame(checks)

# %%
# check mismatches 

false_matches = {}
for specie in species_list:
    # make individual dfs per sp 
    df = checks_df[checks_df['Species']==specie]
    df.head(2)

    # exclude 122024 since no samples were taken 
    df = df[df['Month_year'] != 122024]
    
    # filter for where the match is false or if the colony condition is na and create a new df 
    false = df[(df['Match'] == False) & (~df['colony_condition'].isna())]
    
    # store false matches in new dictionary with species name as key 
    false_matches[specie] = false

# %%
species_list
# Out:
# ['OFAV',
#  'SSID',
#  'PAST',
#  'PSTR',
#  'MCAV',
#  'OANN',
#  'DLAB',
#  'CNAT',
#  'MMEA',
#  'Unknown']

# %%
false_matches['OFAV']
# Out:
#       colony_id Species immune_y/n Date_InitialTag  Month_year  Match  \
# 392  T2_80_OFAV    OFAV          n         5/24/22       92023  False
# 696  T4_77_OFAV    OFAV          n         12/5/22       92023  False
#
#     colony_condition                    sample_condition  \
# 392          CLP,CLB  [Diseased_Margin, Diseased_Tissue]
# 696          Healthy  [Diseased_Tissue, Diseased_Margin]
#
#                                             sample_ids mortality_date
# 392  [092023_BEL_CBC_T2_191_OFAV, 092023_BEL_CBC_T2...       Diseased
# 696  [092023_BEL_CBC_T4_90_OFAV, 092023_BEL_CBC_T4_...        Healthy

# %%
false_matches['SSID']
# why do we have some that say not visited but we have samples for..
# Out:
#       colony_id Species immune_y/n Date_InitialTag  Month_year  Match  \
# 3    T1_11_SSID    SSID          n         6/24/19       42024  False
# 7    T1_11_SSID    SSID          n         6/24/19       92023  False
# 34   T1_17_SSID    SSID          n         6/24/19       42024  False
# 38   T1_17_SSID    SSID          n         6/24/19       92023  False
# 43    T1_1_SSID    SSID          n         6/21/19       42024  False
# 47    T1_1_SSID    SSID          n         6/21/19       92023  False
# 121   T1_3_SSID    SSID          y         6/21/19       22024  False
# 123   T1_3_SSID    SSID          y         6/21/19       52022  False
# 127   T1_3_SSID    SSID          y         6/21/19       82024  False
# 128   T1_3_SSID    SSID          y         6/21/19       92023  False
# 154   T1_9_SSID    SSID          n         6/21/19       42024  False
# 158   T1_9_SSID    SSID          n         6/21/19       92023  False
# 191  T2_51_SSID    SSID          n         6/25/19       52022  False
# 196  T2_52_SSID    SSID          n         6/25/19       62025  False
# 285  T2_66_SSID    SSID          n         6/25/19       92023  False
# 289  T2_67_SSID    SSID          n         6/21/19       92023  False
# 317  T2_71_SSID    SSID          n         6/22/19       42024  False
# 321  T2_71_SSID    SSID          n         6/22/19       92023  False
# 325  T2_72_SSID    SSID          y         6/25/19       42024  False
# 326  T2_72_SSID    SSID          y         6/25/19       52022  False
# 328  T2_72_SSID    SSID          y         6/25/19       62024  False
# 333  T2_72_SSID    SSID          y         6/25/19      122022  False
# 340  T2_73_SSID    SSID          y         6/25/19       62024  False
# 351  T2_74_SSID    SSID          n         6/22/19       92023  False
# 353  T2_75_SSID    SSID          n         6/21/19       42024  False
# 356  T2_75_SSID    SSID          n         6/21/19       92023  False
# 396  T2_99_SSID    SSID          y         6/21/24       42024  False
# 397  T2_99_SSID    SSID          y         6/21/24       62024  False
# 443  T3_19_SSID    SSID          n         6/23/19       42024  False
# 477  T3_23_SSID    SSID          n         6/23/19       62025  False
# 478  T3_23_SSID    SSID          n         6/23/19       92023  False
# 489  T3_28_SSID    SSID          n         6/23/19       92023  False
# 509  T3_33_SSID    SSID          y         6/23/19       12024  False
# 510  T3_33_SSID    SSID          y         6/23/19       22024  False
# 511  T3_33_SSID    SSID          y         6/23/19       42024  False
# 514  T3_33_SSID    SSID          y         6/23/19       62024  False
# 516  T3_33_SSID    SSID          y         6/23/19       82024  False
# 517  T3_33_SSID    SSID          y         6/23/19       92023  False
# 520  T3_33_SSID    SSID          y         6/23/19      122023  False
# 538  T3_36_SSID    SSID          n         6/23/19       92023  False
# 588  T3_65_SSID    SSID          n         6/23/19       42024  False
# 592  T3_65_SSID    SSID          n         6/23/19       92023  False
#
#     colony_condition                    sample_condition  \
# 3           Diseased                   [Diseased_Margin]
# 7           Diseased                   [Diseased_Margin]
# 34     Diseased, CLP  [Diseased_Tissue, Diseased_Margin]
# 38     Diseased, CLB  [Diseased_Tissue, Diseased_Margin]
# 43          Diseased                   [Diseased_Margin]
# 47          Diseased                   [Diseased_Margin]
# 121         Diseased                           [Healthy]
# 123         Diseased                   [Diseased_Tissue]
# 127         Diseased                           [Healthy]
# 128         Diseased                           [Healthy]
# 154         Diseased                   [Diseased_Margin]
# 158         Diseased                   [Diseased_Margin]
# 191         Diseased                   [Diseased_Tissue]
# 196         Diseased                   [Diseased_Margin]
# 285              CLB                   [Diseased_Margin]
# 289              CLB                   [Diseased_Margin]
# 317         Diseased                   [Diseased_Margin]
# 321              CLP                   [Diseased_Margin]
# 325         Diseased                           [Healthy]
# 326           CLB,DC                           [Healthy]
# 328         Diseased                   [Diseased_Tissue]
# 333           CLB,DC                           [Healthy]
# 340               DC                           [Healthy]
# 351         Diseased          [Healthy, Diseased_Margin]
# 353         Diseased                   [Diseased_Margin]
# 356         Diseased                   [Diseased_Margin]
# 396               DC  [Diseased_Tissue, Diseased_Margin]
# 397         Diseased                   [Diseased_Tissue]
# 443         Diseased                   [Diseased_Tissue]
# 477         Diseased                   [Diseased_Margin]
# 478         Diseased                   [Diseased_Margin]
# 489         Diseased  [Diseased_Tissue, Diseased_Tissue]
# 509               DC                           [Healthy]
# 510               DC                           [Healthy]
# 511               DC                           [Healthy]
# 514               DC                           [Healthy]
# 516               DC                           [Healthy]
# 517           CLP,DC                           [Healthy]
# 520               DC                           [Healthy]
# 538               DC                           [Healthy]
# 588      Not_Visited                   [Diseased_Margin]
# 592      Not_Visited  [Diseased_Tissue, Diseased_Margin]
#
#                                             sample_ids mortality_date
# 3                         [042024_BEL_CBC_T1_936_SSID]       Diseased
# 7                         [092023_BEL_CBC_T1_193_SSID]       Diseased
# 34   [042024_BEL_CBC_T1_940_SSID, 042024_BEL_CBC_T1...       Diseased
# 38   [092023_BEL_CBC_T1_196_SSID, 092023_BEL_CBC_T1...       Diseased
# 43                        [042024_BEL_CBC_T1_937_SSID]       Diseased
# 47                        [092023_BEL_CBC_T1_185_SSID]       Diseased
# 121                       [022024_BEL_CBC_T1_773_SSID]       Diseased
# 123                         [052022_BEL_CBC_T1_2_SSID]       Diseased
# 127                      [082024_BEL_CBC_T1_1480_SSID]       Diseased
# 128                       [092023_BEL_CBC_T1_173_SSID]       Diseased
# 154                       [042024_BEL_CBC_T1_935_SSID]       Diseased
# 158                       [092023_BEL_CBC_T1_192_SSID]       Diseased
# 191                        [052022_BEL_CBC_T2_27_SSID]        12/1/22
# 196                      [062025_BEL_CBC_T2_1858_SSID]       Diseased
# 285                       [092023_BEL_CBC_T2_189_SSID]       Diseased
# 289                       [092023_BEL_CBC_T2_190_SSID]        6/21/24
# 317                      [042024_BEL_CBC_T2_1039_SSID]       Diseased
# 321                       [092023_BEL_CBC_T2_187_SSID]       Diseased
# 325                      [042024_BEL_CBC_T2_1040_SSID]        Healthy
# 326                         [052022_BEL_CBC_T2_3_SSID]        Healthy
# 328                      [062024_BEL_CBC_T2_1369_SSID]        Healthy
# 333                        [122022_BEL_CBC_T2_96_SSID]        Healthy
# 340                      [062024_BEL_CBC_T2_1375_SSID]        Healthy
# 351  [092023_BEL_CBC_T2_177_SSID, 092023_BEL_CBC_T2...        Healthy
# 353                      [042024_BEL_CBC_T2_1036_SSID]       Diseased
# 356                       [092023_BEL_CBC_T2_188_SSID]       Diseased
# 396  [042024_BEL_CBC_T2_1034_SSID, 042024_BEL_CBC_T...        Healthy
# 397                      [062024_BEL_CBC_T2_1381_SSID]        Healthy
# 443                      [042024_BEL_CBC_T3_1011_SSID]       Diseased
# 477                      [062025_BEL_CBC_T3_1703_SSID]       Diseased
# 478                       [092023_BEL_CBC_T3_265_SSID]       Diseased
# 489  [092023_BEL_CBC_T3_90_SSID, 092023_BEL_CBC_T3_...       Diseased
# 509                       [012024_BEL_CBC_T3_625_SSID]       Diseased
# 510                       [022024_BEL_CBC_T3_853_SSID]       Diseased
# 511                       [042024_BEL_CBC_T3_944_SSID]       Diseased
# 514                      [062024_BEL_CBC_T3_1445_SSID]       Diseased
# 516                      [082024_BEL_CBC_T3_1563_SSID]       Diseased
# 517                       [092023_BEL_CBC_T3_183_SSID]       Diseased
# 520                       [122023_BEL_CBC_T3_534_SSID]       Diseased
# 538                       [092023_BEL_CBC_T3_190_SSID]       Diseased
# 588                       [042024_BEL_CBC_T3_964_SSID]       Diseased
# 592  [092023_BEL_CBC_T3_264_SSID, 092023_BEL_CBC_T3...       Diseased

# %%
false_matches['PAST']
# no condition mismatch, just missing margin sample?
# Out:
#      colony_id Species immune_y/n Date_InitialTag  Month_year  Match  \
# 40  T1_19_PAST    PAST          n         6/21/19       52022  False
#
#    colony_condition   sample_condition                   sample_ids  \
# 40         Diseased  [Diseased_Tissue]  [052022_BEL_CBC_T1_52_PAST]
#
#    mortality_date
# 40         4/1/24

# %%
false_matches['PSTR']
# Out:
#       colony_id Species immune_y/n Date_InitialTag  Month_year  Match  \
# 207  T2_54_PSTR    PSTR          n        10/13/19       92023  False
# 641  T3_75_PSTR    PSTR          n         12/3/22       42024  False
#
#     colony_condition                    sample_condition  \
# 207    Diseased, CLP  [Diseased_Margin, Diseased_Tissue]
# 641          Healthy  [Diseased_Tissue, Diseased_Margin]
#
#                                             sample_ids mortality_date
# 207  [092023_BEL_CBC_T2_185_PSTR, 092023_BEL_CBC_T2...        Healthy
# 641  [042024_BEL_CBC_T3_965_PSTR, 042024_BEL_CBC_T3...        Healthy

# %%
false_matches['MCAV']
# Out:
#       colony_id Species immune_y/n Date_InitialTag  Month_year  Match  \
# 153   T1_8_MCAV    MCAV          n         6/24/19      122022  False
# 492   T3_2_MCAV    MCAV          y         6/23/19       12024  False
# 494   T3_2_MCAV    MCAV          y         6/23/19       42024  False
# 499   T3_2_MCAV    MCAV          y         6/23/19       82024  False
# 603  T3_67_MCAV    MCAV          n         12/3/22      122022  False
# 631  T3_71_MCAV    MCAV          n         12/3/22      122022  False
# 817  T5_57_MCAV    MCAV          n         1/13/24       12024  False
# 818  T5_57_MCAV    MCAV          n         1/13/24       42024  False
# 830  T5_64_MCAV    MCAV          n         1/13/24       42024  False
# 832  T5_65_MCAV    MCAV          n         1/13/24       12024  False
# 833  T5_65_MCAV    MCAV          n         1/13/24       42024  False
# 838  T5_69_MCAV    MCAV          n         1/13/24       12024  False
# 839  T5_69_MCAV    MCAV          n         1/13/24       42024  False
#
#         colony_condition   sample_condition                     sample_ids  \
# 153             Diseased  [Diseased_Tissue]   [122022_BEL_CBC_T1_144_MCAV]
# 492  Diseased_Other, CLP          [Healthy]   [012024_BEL_CBC_T3_633_MCAV]
# 494       Diseased_Other          [Healthy]   [042024_BEL_CBC_T3_956_MCAV]
# 499       Diseased_Other          [Healthy]  [082024_BEL_CBC_T3_1553_MCAV]
# 603             Diseased  [Diseased_Tissue]   [122022_BEL_CBC_T3_145_MCAV]
# 631                   DC          [Healthy]   [122022_BEL_CBC_T3_155_MCAV]
# 817                   DC          [Healthy]   [012024_BEL_CBC_T5_700_MCAV]
# 818                   DC          [Healthy]  [042024_BEL_CBC_T5_1099_MCAV]
# 830          Not_visited          [Healthy]  [042024_BEL_CBC_T5_1135_MCAV]
# 832                   DC          [Healthy]   [012024_BEL_CBC_T5_708_MCAV]
# 833                   DC          [Healthy]  [042024_BEL_CBC_T5_1130_MCAV]
# 838                   DC          [Healthy]   [012024_BEL_CBC_T5_710_MCAV]
# 839                   DC          [Healthy]  [042024_BEL_CBC_T5_1112_MCAV]
#
#     mortality_date
# 153        9/25/23
# 492       Diseased
# 494       Diseased
# 499       Diseased
# 603        9/25/23
# 631        Healthy
# 817        Healthy
# 818        Healthy
# 830        Healthy
# 832        Healthy
# 833        Healthy
# 838        Healthy
# 839        Healthy

# %%
false_matches['OANN']
# Out:
#       colony_id Species immune_y/n Date_InitialTag  Month_year  Match  \
# 61   T1_22_OANN    OANN          n         5/21/22       42024  False
# 67   T1_23_OANN    OANN          n         5/21/22       52022  False
# 69   T1_23_OANN    OANN          n         5/21/22       92023  False
# 170  T2_30_OANN    OANN          n         12/5/22       92023  False
#
#     colony_condition                    sample_condition  \
# 61               CLP                   [Diseased_Tissue]
# 67                DC                           [Healthy]
# 69               CLB  [Diseased_Tissue, Diseased_Margin]
# 170          CLP,CLB  [Diseased_Margin, Diseased_Tissue]
#
#                                             sample_ids mortality_date
# 61                       [042024_BEL_CBC_T1_1146_OANN]       Diseased
# 67                         [052022_BEL_CBC_T1_35_OANN]        Healthy
# 69   [092023_BEL_CBC_T1_186_OANN, 092023_BEL_CBC_T1...        Healthy
# 170  [092023_BEL_CBC_T2_193_OANN, 092023_BEL_CBC_T2...       Diseased

# %%
false_matches['DLAB']
# Out:
#       colony_id Species immune_y/n Date_InitialTag  Month_year  Match  \
# 118  T1_35_DLAB    DLAB          n         5/25/22      122022  False
# 725  T4_93_DLAB    DLAB          n         12/5/22       92023  False
#
#     colony_condition                    sample_condition  \
# 118               DC                           [Healthy]
# 725          Healthy  [Diseased_Tissue, Diseased_Margin]
#
#                                             sample_ids mortality_date
# 118                         [122022_BEL_CBC_T1_154_DL]        Healthy
# 725  [092023_BEL_CBC_T4_82_DLAB, 092023_BEL_CBC_T4_...        Healthy

# %%
false_matches['CNAT']
# Out:
# Empty DataFrame
# Columns: [colony_id, Species, immune_y/n, Date_InitialTag, Month_year, Match, colony_condition, sample_condition, sample_ids, mortality_date]
# Index: []

# %%
false_matches['MMEA']
# Out:
# Empty DataFrame
# Columns: [colony_id, Species, immune_y/n, Date_InitialTag, Month_year, Match, colony_condition, sample_condition, sample_ids, mortality_date]
# Index: []

# %%
false_matches['Unknown']
# Out:
# Empty DataFrame
# Columns: [colony_id, Species, immune_y/n, Date_InitialTag, Month_year, Match, colony_condition, sample_condition, sample_ids, mortality_date]
# Index: []
